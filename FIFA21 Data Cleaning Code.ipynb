# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Cleaning
#
# ### Create a copy of DataFrame

# %%
data = pd.read_csv('fifa21 raw data v2.csv')
data.sample(10)
# Out:
#            ID              Name                  LongName  \
# 164    208574         F. Kostić              Filip Kostić
# 16697  257017          C. Zabou               Cyril Zabou
# 238    212523  Anderson Talisca  Anderson Souza Conceição
# 5015   183955      T. Chevalier           Teddy Chevalier
# 1507   226078         Trezeguet            Mahmoud Hassan
# 17608  251199         M. Fofana           Mustapha Fofana
# 14415  211598        M. Arteaga            Manuel Arteaga
# 11325  254585       J. Palacios           Julián Palacios
# 3342   245598           I. Baba              Iddrisu Baba
# 11748  239145      E. Massouema            Eden Massouema
#
#                                                photoUrl  \
# 164    https://cdn.sofifa.com/players/208/574/21_60.png
# 16697  https://cdn.sofifa.com/players/257/017/21_60.png
# 238    https://cdn.sofifa.com/players/212/523/21_60.png
# 5015   https://cdn.sofifa.com/players/183/955/21_60.png
# 1507   https://cdn.sofifa.com/players/226/078/21_60.png
# 17608  https://cdn.sofifa.com/players/251/199/21_60.png
# 14415  https://cdn.sofifa.com/players/211/598/21_60.png
# 11325  https://cdn.sofifa.com/players/254/585/21_60.png
# 3342   https://cdn.sofifa.com/players/245/598/21_60.png
# 11748  https://cdn.sofifa.com/players/239/145/21_60.png
#
#                                                               playerUrl  \
# 164                http://sofifa.com/player/208574/filip-kostic/210006/
# 16697               http://sofifa.com/player/257017/cyril-zabou/210006/
# 238    http://sofifa.com/player/212523/anderson-souza-conceicao/210006/
# 5015            http://sofifa.com/player/183955/teddy-chevalier/210006/
# 1507             http://sofifa.com/player/226078/mahmoud-hassan/210006/
# 17608           http://sofifa.com/player/251199/mustapha-fofana/210006/
# 14415            http://sofifa.com/player/211598/manuel-arteaga/210006/
# 11325           http://sofifa.com/player/254585/julian-palacios/210006/
# 3342               http://sofifa.com/player/245598/iddrisu-baba/210006/
# 11748            http://sofifa.com/player/239145/eden-massouema/210006/
#
#       Nationality  Age  ↓OVA  POT                                    Club  \
# 164        Serbia   27    83   83             \n\n\n\nEintracht Frankfurt
# 16697      France   24    58   64                 \n\n\n\nFC Chambly Oise
# 238        Brazil   26    82   85  \n\n\n\nGuangzhou Evergrande Taobao FC
# 5015       France   33    70   70                 \n\n\n\nValenciennes FC
# 1507        Egypt   25    75   76                     \n\n\n\nAston Villa
# 17608      Norway   19    55   75                 \n\n\n\nStrømsgodset IF
# 14415   Venezuela   26    61   64                       \n\n\n\nZamora FC
# 11325   Argentina   21    64   78          \n\n\n\nSan Lorenzo de Almagro
# 3342        Ghana   24    72   81                    \n\n\n\nRCD Mallorca
# 11748      France   23    64   73                    \n\n\n\nESTAC Troyes
#
#           Contract   Positions Height Weight Preferred Foot  BOV  \
# 164    2019 ~ 2023     LM, LWB  184cm   82kg           Left   83
# 16697  2020 ~ 2021         CAM  180cm   75kg          Right   60
# 238    2019 ~ 2022     CAM, RW  190cm   80kg           Left   84
# 5015   2019 ~ 2022      ST, RW  178cm   77kg          Right   71
# 1507   2019 ~ 2023  LW, RW, RM  179cm   78kg          Right   76
# 17608  2019 ~ 2021          ST  185cm   65kg          Right   57
# 14415  2017 ~ 2024          ST  185cm   78kg          Right   63
# 11325  2019 ~ 2023          RM  172cm   65kg          Right   65
# 3342   2018 ~ 2024     CDM, CM  185cm   73kg          Right   73
# 11748  2019 ~ 2022     CM, CDM  184cm   71kg          Right   67
#
#       Best Position     Joined Loan Date End   Value  Wage Release Clause  \
# 164              LM  17-May-19           NaN  €38.5M  €45K         €45.9M
# 16697           CAM  28-Jun-20           NaN   €325K  €850          €332K
# 238             CAM  01-Jan-19           NaN    €40M  €36K         €46.1M
# 5015             RW  20-Jul-19           NaN     €1M   €5K          €1.9M
# 1507             RM  25-Jul-19           NaN   €6.5M  €51K         €15.8M
# 17608            ST  27-Jun-19           NaN   €350K  €600          €383K
# 14415            ST  01-Jul-17           NaN   €425K  €500          €723K
# 11325            RM  08-Dec-19           NaN   €1.4M   €4K          €2.1M
# 3342            CDM  01-Jul-18           NaN   €4.9M   €6K          €7.9M
# 11748           CDM  01-Jul-19           NaN   €1.3M   €2K          €1.4M
#
#        Attacking  Crossing  Finishing  Heading Accuracy  Short Passing  \
# 164          367        89         74                59             75
# 16697        228        39         46                22             58
# 238          392        75         80                77             84
# 5015         342        70         74                58             65
# 1507         331        75         75                42             76
# 17608        225        31         58                52             46
# 14415        283        40         63                70             60
# 11325        298        61         62                52             69
# 3342         265        43         46                63             71
# 11748        263        49         38                62             70
#
#        Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing  \
# 164         70    400         85     79           80            73
# 16697       63    287         69     64           42            44
# 238         76    421         82     86           87            82
# 5015        75    338         71     70           69            58
# 1507        63    356         80     63           63            72
# 17608       38    212         56     38           29            35
# 14415       50    255         62     47           36            39
# 11325       54    292         64     56           46            63
# 3342        42    279         54     46           48            66
# 11748       44    294         62     52           47            67
#
#        Ball Control  Movement  Acceleration  Sprint Speed  Agility  Reactions  \
# 164              83       410            89            87       76         81
# 16697            68       338            78            79       76         41
# 238              84       400            84            76       87         78
# 5015             70       367            74            76       72         68
# 1507             78       376            79            82       78         67
# 17608            54       326            73            76       63         51
# 14415            71       285            55            52       63         54
# 11325            63       355            76            75       73         49
# 3342             65       302            65            64       49         62
# 11748            66       319            63            66       68         63
#
#        Balance  Power  Shot Power  Jumping  Stamina  Strength  Long Shots  \
# 164         77    397          84       67       91        77          78
# 16697       64    169          48       26       28        31          36
# 238         75    393          84       65       82        75          87
# 5015        77    371          74       83       70        72          72
# 1507        70    362          76       65       78        67          76
# 17608       63    277          52       64       49        64          48
# 14415       61    317          61       68       66        65          57
# 11325       82    291          64       65       66        40          56
# 3342        62    323          56       59       80        76          52
# 11748       59    325          66       66       71        72          50
#
#        Mentality  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 164          365          78             63           79      81         64
# 16697        179          22             12           53      51         41
# 238          359          67             52           86      79         75
# 5015         317          74             38           71      69         65
# 1507         275          45             22           69      65         74
# 17608        202          40             15           48      45         54
# 14415        218          42             13           52      49         62
# 11325        277          62             46           53      61         55
# 3342         309          80             75           43      59         52
# 11748        293          59             64           61      58         51
#
#        Composure  Defending  Marking  Standing Tackle  Sliding Tackle  \
# 164           80        209       69               72              68
# 16697         62         57       18               18              21
# 238           77        148       51               55              42
# 5015          74         92       30               29              33
# 1507          74        105       39               39              27
# 17608         50         36       11               12              13
# 14415         65         78       39               15              24
# 11325         67        154       47               55              52
# 3342          53        216       67               76              73
# 11748         59        187       57               68              62
#
#        Goalkeeping  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 164             64         13           14          12              12
# 16697           51          7            9          13              14
# 238             59         13           11          13              12
# 5015            62          7            8          16              16
# 1507            50          8           10          15              10
# 17608           46         13            7          11               9
# 14415           54          9           13           9              15
# 11325           48          7           10           9               9
# 3342            49         10            9          10              14
# 11748           58         15           11          14              12
#
#        GK Reflexes  Total Stats  Base Stats  W/F  SM     A/W     D/W   IR  \
# 164             13         2212         474  2 ★  3★    High    High  2 ★
# 16697            8         1309         288  4 ★  3★  Medium     Low  1 ★
# 238             10         2172         455  4 ★  4★    High     Low  2 ★
# 5015            15         1889         391  3 ★  3★    High  Medium  1 ★
# 1507             7         1855         405  5 ★  4★    High  Medium  3 ★
# 17608            6         1324         295  3 ★  2★  Medium  Medium  1 ★
# 14415            8         1490         315  3 ★  2★  Medium     Low  1 ★
# 11325           13         1715         365  3 ★  3★  Medium  Medium  1 ★
# 3342             6         1743         380  4 ★  2★  Medium    High  1 ★
# 11748            6         1739         370  3 ★  2★  Medium  Medium  1 ★
#
#        PAC  SHO  PAS  DRI  DEF  PHY Hits
# 164     88   76   79   83   68   80   87
# 16697   79   45   50   68   18   28  NaN
# 238     80   82   81   83   54   75  159
# 5015    75   73   66   71   34   72    1
# 1507    81   74   72   78   35   65   60
# 17608   75   53   40   56   16   55  NaN
# 14415   53   60   49   64   28   61    2
# 11325   75   60   63   65   50   52    9
# 3342    64   49   60   58   72   77   40
# 11748   65   48   61   64   63   69    4

# %% [markdown]
# ### 1. ID
#
# Unique identifier for each player.

# %% [markdown]
# ### 2. Name
#
# Player's name

# %% [markdown]
# ### 3. LongName
#
# Player's full name

# %% [markdown]
# ### 4. photoURL
#
# URL to player's photo

# %% [markdown]
# ### 5. playerURL
#
# URL to player's profile

# %% [markdown]
# ### 6. Nationality
#
# Player's nationality

# %% [markdown]
# ### 7. Age
#
# Player's age in years

# %% [markdown]
# ### 8. OVA - Overall Rating (0-100)
#
# It is a rating system used to represent a player's overall abilities and skills in the game.

# %% [markdown]
# ### 9. POT - Potential Rating(0-100)
#
# Represent a player's potential to develop and improve their abilities and skills over time.

# %% [markdown]
# ### 10. Club
#
# Current Club of the player

# %% [markdown]
# ### 11. Contract column

# %% [markdown]
# ### 12. Positions
#
# Player's preferred position on the field

# %% [markdown]
# ### 13. Height

# %% [markdown]
# ### 14. Weight

# %% [markdown]
# ### 15. Preferred Foot
#
# Player's preferred foot - Left or Right

# %% [markdown]
# ### 16. BOV
#
# Best Overall Rating of the Player in a specific position

# %% [markdown]
# ### 17. Best Position
#
# Player's best position on the field

# %% [markdown]
# ### 18. Joined
#
# Date when the player joined the current club

# %% [markdown]
# ### 19. Loan Date End
#
# Date when the player's loan ends (if On Loan)

# %% [markdown]
# ### 20. Value
#
# Estimated market value of the player.

# %% [markdown]
# ### 21. Wage
#
# Weekly wage of the player.

# %% [markdown]
# ### 22. Release Clause
#
# Release clause in the player's contract

# %% [markdown]
# ### 23. Attacking
#
# Composite rating of the player's attacking ability.

# %% [markdown]
# ### 24. Crossing
#
# Player's ability to make accurate crosses.

# %% [markdown]
# ### 25. Finishing
#
# Player's ability to score goals

# %% [markdown]
# ### 26. Heading Accuracy
#
# Player's ability to win aerial duels.

# %% [markdown]
# ### 27. Short Passing
#
# Player's ability to make short passes accurately.

# %% [markdown]
# ### 28. Volleys
#
# Player's ability to take volleys

# %% [markdown]
# ### 29. Skill
#
# Composite rating of the player's technical abilities.

# %% [markdown]
# ### 30. Dribbling
#
# Player's ability to dribble past defenders.

# %% [markdown]
# ### 31. Curve
#
# Player's ability to curve the ball.

# %% [markdown]
# ### 32. FK Accuracy
#
# Player's ability to take free kicks.

# %% [markdown]
# ### 33. Long Passing
#
# Player's ability to make long passes accurately.

# %% [markdown]
# ### 34. Ball Control
#
# Player's ability to control the ball.

# %% [markdown]
# ### 35. Movement
#
# Composite rating of the player's movement abilities.

# %% [markdown]
# ### 36. Acceleration
#
# Playr's ability to accelerate quickly.

# %% [markdown]
# ### 37. Sprint Speed
#
# Player's top speed

# %% [markdown]
# ### 38. Agility
#
# Player's agility

# %% [markdown]
# ### 39. Reactions
#
# Player's reaction time

# %% [markdown]
# ### 40. Balance
#
# Player's balance

# %% [markdown]
# ### 41. Power
#
# Composite rating of player's physical abilities

# %% [markdown]
# ### 42. Shot Power
#
# Player's ability to shoot with power

# %% [markdown]
# ### 43. Jumping
#
# Player's ability to jump high

# %% [markdown]
# ### 44. Stamina
#
# Player's stamina.

# %% [markdown]
# ### 45. Strength
#
# Player's physical strength.

# %% [markdown]
# ### 46. Long Shots
#
# Player's ability to score from long range

# %% [markdown]
# ### 47. Mentality
#
# Composite rating of the player's mental abilities.

# %% [markdown]
# ### 48. Aggression
#
# Player's aggression on the field.

# %% [markdown]
# ### 49. Interceptions
#
# Player's ability to intercept passes.

# %% [markdown]
# ### 50. Positioning
#
# Player's ability to position themselves well on the field.

# %% [markdown]
# ### 51. Vision
#
# Players ability to see and execute passes.

# %% [markdown]
# ### 52. Penalties
#
# Player's ability to score penalties.

# %% [markdown]
# ### 53. Composure
#
# Player's composure under pressure.

# %% [markdown]
# ### 54. Defending
#
# Composite rating of the player's defensive abilities.

# %% [markdown]
# ### 55. Marking
#
# Player's ability to mark opposing players.

# %% [markdown]
# ### 56. Standing Tackle
#
# Player's ability to make standing tackles.

# %% [markdown]
# ### 57. Sliding Tackle
#
# Player's ability to make sliding tackles.

# %% [markdown]
# ### 58. Goalkeeping
#
# Composite rating of the player's goalkeeping abilities. Only for goalkeepers

# %% [markdown]
# ### 59. GK Diving
#
# Goalkeeper's ability to dive to make saves.

# %% [markdown]
# ### 60. GK Handling
#
# Goalkeeper's ability to handle the ball

# %% [markdown]
# ### 61. GK Kicking
#
# Goalkeeper's ability to kick the ball.

# %% [markdown]
# ### 62. GK Positioning
#
# Goalkeeper's ability to position themselves well.

# %% [markdown]
# ### 63. GK Reflexes
#
# Goalkeeper's reflexes

# %% [markdown]
# ### 64. Total Stats
#
# Total number of stats in the game

# %% [markdown]
# ### 65. Base Stats
#
# Number of stats used to calculate the player's overall rating.

# %% [markdown]
# ### 66. W/F
#
# Player's weak foot rating (out of 5)

# %% [markdown]
# ### 67. SM
#
# Player's skill moves rating (out of 5)

# %% [markdown]
# ### 68. A/W
#
# Player's attacking work rate (low, medium or high)

# %% [markdown]
# ### 69. D/W
#
# Player's defensive work rate (low, medium or high)

# %% [markdown]
# ### 70. IR
#
# Player's injury resistance rating (out of 3)

# %% [markdown]
# ### 71. PAC
#
# Player's pace attribute rating(0-100).
#
# It measures the player's speed on the pitch, including their acceleration and sprinting ability.
#
# A higher PAC value indicates that the player is faster.

# %% [markdown]
# ### 72. SHO
#
# Player's shooting attribute rating.(0-100)

# %% [markdown]
# ### 73. PAS
#
# Player's passing attribute rating.(0-100)

# %% [markdown]
# ### 74. DRI
#
# Player's dribbling attribute rating.(0-100)

# %% [markdown]
# ### 75. DEF
#
# Player's defending attribute rating.

# %% [markdown]
# ### 76. PHY
#
# Player's physical attribute rating.

# %% [markdown]
# ### 77. Hits
#
# Number of times the player has been searched for in the FIFA database.

# %% [markdown]
# ### Look at dtypes of all columns
